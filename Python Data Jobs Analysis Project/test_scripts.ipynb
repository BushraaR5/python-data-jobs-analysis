# %%
import src.data_cleaning

dir(src.data_cleaning)
# Out:
# ['Path',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'ast',
#  'defaultdict',
#  'hashlib',
#  'load_and_clean_data',
#  'load_csv_with_parsing',
#  'pd']

# %%
from src.data_cleaning import load_and_clean_data

#df = load_and_clean_data() #no file save
df = load_and_clean_data(save=True) #saves files
# Out:
# Using sample dataset

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT     [Work Nearby]         Full-time
# 1  Guadalajara, Jalisco, Mexico    [BeBee México]         Full-time
# 2               Berlin, Germany        [LinkedIn]         Full-time
# 3               San Antonio, TX   [Diversity.com]         Full-time
# 4                Washington, DC  [Clearance Jobs]         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
import pandas as pd
df = pd.read_csv('cleaned_jobs.csv')
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     ['Work Nearby']         Full-time
# 1  Guadalajara, Jalisco, Mexico    ['BeBee México']         Full-time
# 2               Berlin, Germany        ['LinkedIn']         Full-time
# 3               San Antonio, TX   ['Diversity.com']         Full-time
# 4                Washington, DC  ['Clearance Jobs']         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
import pandas as pd
df = pd.read_pickle('cleaned_jobs.pkl')
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT     [Work Nearby]         Full-time
# 1  Guadalajara, Jalisco, Mexico    [BeBee México]         Full-time
# 2               Berlin, Germany        [LinkedIn]         Full-time
# 3               San Antonio, TX   [Diversity.com]         Full-time
# 4                Washington, DC  [Clearance Jobs]         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
from src.data_cleaning import load_csv_with_parsing

df1 = load_csv_with_parsing()

# %%
df1.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     ['Work Nearby']         Full-time
# 1  Guadalajara, Jalisco, Mexico    ['BeBee México']         Full-time
# 2               Berlin, Germany        ['LinkedIn']         Full-time
# 3               San Antonio, TX   ['Diversity.com']         Full-time
# 4                Washington, DC  ['Clearance Jobs']         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df1['job_type_skills'][1]
# Out:
# {'analyst_tools': ['power bi', 'tableau'],
#  'programming': ['nosql', 'python', 'r', 'sql']}

# %%
import pandas as pd
# import sys
# import os

#sys.path.append(os.path.abspath(".."))

from src.skills_processing import create_skills_df

df = pd.read_pickle("data/processed/cleaned_jobs.pkl")

skills_df = create_skills_df(df)

# %%
skills_df
# Out:
#                 job_id    job_title_short       category     skill
# 1       J-64833455be38       Data Analyst  analyst_tools  power bi
# 1       J-64833455be38       Data Analyst  analyst_tools   tableau
# 1       J-64833455be38       Data Analyst    programming     nosql
# 1       J-64833455be38       Data Analyst    programming    python
# 1       J-64833455be38       Data Analyst    programming         r
# ...                ...                ...            ...       ...
# 785739  J-a94d273e8878      Data Engineer    programming    python
# 785739  J-a94d273e8878      Data Engineer    programming     shell
# 785739  J-a94d273e8878      Data Engineer    programming       sql
# 785740  J-03b27285205d  Software Engineer          cloud       aws
# 785740  J-03b27285205d  Software Engineer          other      flow
#
# [3593147 rows x 4 columns]
